# %%
# ====== SETUP ======
# !pip install -q ultralytics onnx onnxruntime torch torchvision


import torch
import onnx
from ultralytics import YOLO


print('Torch:', torch.__version__)
print('CUDA available:', torch.cuda.is_available())
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 74.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 94.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 84.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.4 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Torch: 2.9.0+cu126
# CUDA available: True

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download abdallahwagih/cars-detection
# !unzip cars-detection.zip -d cars
# Out:
# Dataset URL: https://www.kaggle.com/datasets/abdallahwagih/cars-detection
# License(s): apache-2.0
# ...
#   0% 0.00/38.2M [00:00<?, ?B/s]
# 100% 38.2M/38.2M [00:00<00:00, 1.69GB/s]
# Archive:  cars-detection.zip
#   inflating: cars/Cars Detection/data.yaml
#   inflating: cars/Cars Detection/test/images/00dea1edf14f09ab_jpg.rf.3f17c8790a68659d03b1939a59ccda80.jpg
#   inflating: cars/Cars Detection/test/images/00dea1edf14f09ab_jpg.rf.KJ730oDTFPdXdJxvSLnX.jpg
#   inflating: cars/Cars Detection/test/images/00e481ea1a520175_jpg.rf.6e6a8b3b45c9a11d106958f88ff714ea.jpg
#   inflating: cars/Cars Detection/test/images/00e481ea1a520175_jpg.rf.MV6sZ8QCFwFeMYaI2tHm.jpg
#   inflating: cars/Cars Detection/test/images/08c8b73e0c2e296e_jpg.rf.7IkYAamjZhnwsoXSrwKt.jpg
#   inflating: cars/Cars Detection/test/images/08c8b73e0c2e296e_jpg.rf.effa65856584463c08848031cab357b9.jpg
#   inflating: cars/Cars Detection/test/images/10c26c6598677a1f_jpg.rf.USCbBYVcUICkLhuq07Lw.jpg
# ...

# %%
model = YOLO('yolov8n.pt')
model
# Out:
# ...
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
import os

label_dir = "/content/cars/Cars Detection/train/labels"
files = os.listdir(label_dir)[:5]

for f in files:
    print(f)
    with open(os.path.join(label_dir, f)) as txt:
        print(txt.read())
# Out:
# 1dbc8d811c800ef7_jpg.rf.5X5S6sH5woR5ul2ERKfy.txt
# 0 0.5036057692307693 0.45072115384615385 0.90625 0.8076923076923077
# 8ee800b43a4797d5_jpg.rf.e2a2f10042859edddd186b45562208f8.txt
# 3 0.5697115384615384 0.6418269230769231 0.2776442307692308 0.4110576923076923
# 0158307c4ad94b38_jpg.rf.7c3ac0278eaf3a1773359994c4679aca.txt
# 0 0.4963942307692308 0.515625 0.8149038461538461 0.6262019230769231
# 592e3df4fde8793d_jpg.rf.976496d831c40f9941072b214da6aff1.txt
# 2 0.4254807692307692 0.5192307692307693 0.14543269230769232 0.17908653846153846
# 2 0.5288461538461539 0.46153846153846156 0.054086538461538464 0.06370192307692307
# 2 0.6466346153846154 0.41947115384615385 0.03125 0.014423076923076924
# 2 0.6526442307692307 0.4483173076923077 0.03365384615384615 0.04447115384615385
# bdb39aad895c90c6_jpg.rf.3d6dbe49dd09f4d6b6c375ac1e9a909f.txt
# 2 0.03485576923076923 0.26322115384615385 0.06971153846153846 0.13701923076923078
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/cars/Cars Detection/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    device=0
)
# Out:
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO("runs/detect/train2/weights/best.pt")
results = model("/content/cars/Cars Detection/test/images", save=True)
# Out:
# image 1/126 /content/cars/Cars Detection/test/images/00dea1edf14f09ab_jpg.rf.3f17c8790a68659d03b1939a59ccda80.jpg: 640x640 1 Ambulance, 8.1ms
# image 2/126 /content/cars/Cars Detection/test/images/00dea1edf14f09ab_jpg.rf.KJ730oDTFPdXdJxvSLnX.jpg: 640x640 1 Ambulance, 7.2ms
# image 3/126 /content/cars/Cars Detection/test/images/00e481ea1a520175_jpg.rf.6e6a8b3b45c9a11d106958f88ff714ea.jpg: 640x640 3 Buss, 7.2ms
# image 4/126 /content/cars/Cars Detection/test/images/00e481ea1a520175_jpg.rf.MV6sZ8QCFwFeMYaI2tHm.jpg: 640x640 3 Buss, 7.1ms
# image 5/126 /content/cars/Cars Detection/test/images/08c8b73e0c2e296e_jpg.rf.7IkYAamjZhnwsoXSrwKt.jpg: 640x640 3 Buss, 1 Motorcycle, 7.1ms
# image 6/126 /content/cars/Cars Detection/test/images/08c8b73e0c2e296e_jpg.rf.effa65856584463c08848031cab357b9.jpg: 640x640 3 Buss, 1 Motorcycle, 11.7ms
# image 7/126 /content/cars/Cars Detection/test/images/10c26c6598677a1f_jpg.rf.USCbBYVcUICkLhuq07Lw.jpg: 640x640 (no detections), 10.3ms
# ...

# %%
model.export(
    format="onnx",
    imgsz=640,
    opset=16,
    dynamic=False,
    simplify=True
)
# Out:
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.00GHz)
#
# PyTorch: starting from 'runs/detect/train2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 9, 8400) (6.0 MB)
#
# ONNX: starting export with onnx 1.20.0 opset 16...
# ONNX: slimming with onnxslim 0.1.80...
# ONNX: export success ✅ 1.0s, saved as 'runs/detect/train2/weights/best.onnx' (11.7 MB)
#
# Export complete (1.3s)
# Results saved to /content/runs/detect/train2/weights
# Predict:         yolo predict task=detect model=runs/detect/train2/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train2/weights/best.onnx imgsz=640 data=/content/cars/Cars Detection/data.yaml
# Visualize:       https://netron.app
# 'runs/detect/train2/weights/best.onnx'

# %%
from google.colab import files
files.download('/content/runs/detect/train2/weights/best.onnx')
